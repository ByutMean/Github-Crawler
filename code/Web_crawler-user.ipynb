# %%
import pandas as pd
import requests
from selenium import webdriver
import time
import random
from tqdm.notebook import tqdm
import requests
#pip install request
#pip install beautifulsoup4
from bs4 import BeautifulSoup

# %%
url_zip=pd.read_csv('git_url_file.csv')

# %%
url_zip
# Out:
#       Unnamed: 0                                                  0
# 0              0  https://github.com/exacity/deeplearningbook-ch...
# 1              1  https://github.com/floodsung/Deep-Learning-Pap...
# 2              2     https://github.com/priya-dwivedi/Deep-Learning
# 3              3   https://github.com/fchollet/deep-learning-models
# 4              4  https://github.com/MichalDanielDobrzanski/Deep...
# ...          ...                                                ...
# 9983        9995       https://github.com/mallicksumit/DeepLearning
# 9984        9996           https://github.com/martahal/DeepLearning
# 9985        9997         https://github.com/fengyemuse/DeepLearning
# 9986        9998            https://github.com/deno750/DeepLearning
# 9987        9999        https://github.com/songyeehong/DeepLearning
#
# [9988 rows x 2 columns]

# %%
from selenium import webdriver
driver = webdriver.Chrome('chromedriver')

# %%
cont_zip=[]
for i in url_zip['0']:
    temp=i+'/graphs/contributors'
    cont_zip.append(temp)

# %%
conts=[]

for url in tqdm(cont_zip):
    driver.get(url)
    time.sleep(3)
    html = driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    try:
        cont_len=len(soup.find_all('li',{'class':'contrib-person float-left col-6 my-2 pr-2'}))
        cont_name=[]
        cont_commit=[]
        cont_add=[]
        cont_delete=[]
        if cont_len>=5:
            for i in range(5):
                name=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/a[2]').text
                cont_name.append(name)
                commit=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/span[2]/span/div/a').text.replace(' commits','')
                cont_commit.append(commit)
                add=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/span[2]/span/div/span[1]').text.replace(' ++','')
                cont_add.append(add)
                delete=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/span[2]/span/div/span[2]').text.replace(' --','')
                cont_delete.append(delete)
            conts.append([cont_name,cont_commit,cont_add,cont_delete])

        else:
            for i in range(cont_len):
                name=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/a[2]').text
                cont_name.append(name)
                commit=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/span[2]/span/div/a').text.replace(' commits','')
                cont_commit.append(commit)
                add=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/span[2]/span/div/span[1]').text.replace(' ++','')
                cont_add.append(add)
                delete=driver.find_element_by_xpath('//*[@id="contributors"]/ol/li['+str(i+1)+']/span/h3/span[2]/span/div/span[2]').text.replace(' --','')
                cont_delete.append(delete)
            conts.append([cont_name,cont_commit,cont_add,cont_delete])
    except:
        pass
# Out:
#   0%|          | 0/9988 [00:00<?, ?it/s]

# %%
cont_name=[]
cont_commit=[]
cont_add=[]
cont_delete=[]

# %%
from pandas import Series
contributors_list=[]
for i in range(9988):
    for j in conts[i][0]:
        contributors_list.append(j)

# %%
new_contributors_list=set(contributors_list)

# %%
len(new_contributors_list)
# Out:
# 8448

# %%
repo_cont
for i in conts:
    user_type.append(i[0])
    user_company.append(i[1])
    user_description.append(i[2])
    user_repos.append(i[3])
    user_gists.append(i[4])
    user_followers.append(i[5])
    user_following.append(i[6])
    user_date.append(i[7])

# %%
from pandas import Series
a=Series(data=conts)
a.to_csv('new_git_contributor.csv')

# %%
repo_cont=[]
for i in conts:
    for j in i:
        repo_cont.append(j)

# %%
cont_name=[]
for i in repo_cont[::4]:
    cont_name.append(i)

# %%
cont_commit=[]
for i in repo_cont[1::4]:
    cont_commit.append(i)
# Out:
# [['208', '164', '84', '37', '4'],
#  ['3', '3', '2', '2', '2'],
#  ['173'],
#  ['11'],
#  ['9', '2', '1 commit'],
#  ['221'],
#  ['2', '1 commit', '1 commit'],
#  ['20', '5', '2'],
#  ['646', '5', '2', '1 commit', '1 commit'],
#  ['90', '1 commit'],
#  ['249'],
#  ['159', '1 commit'],
#  ['109', '9', '6', '5', '4'],
#  ['178', '24', '13', '5', '4'],
#  ['162'],
#  ['54'],
#  ['15', '13', '10', '8', '6'],
#  ['2'],
#  ['83'],
#  ['76', '4', '1 commit', '1 commit'],
#  ['2,592', '4', '3', '2', '2'],
#  ['84'],
#  ['123', '2', '2', '1 commit'],
#  ['15', '9', '5', '4', '4'],
#  ['48'],
#  ['49', '10', '9', '2', '2'],
#  ['1,323', '137', '13', '13', '6'],
#  ['8', '1 commit'],
#  ['5'],
#  ['32'],
#  ['55', '13'],
#  ['186', '2', '2', '1 commit'],
#  ['45', '1 commit'],
#  ['166'],
#  ['61'],
#  ['1 commit'],
#  ['17', '2', '2', '1 commit'],
#  ['14'],
#  ['413', '273', '207', '201', '148'],
#  ['12'],
#  ['51'],
#  ['551', '7', '5', '5', '2'],
#  ['65'],
#  [],
# ...

# %%
new_cont_commit=[]
for i in cont_commit:
    temp=[]
    for j in i:
        j_re=j.replace(' commit','')
        temp.append(j_re)
    new_cont_commit.append(temp)

# %%
real_cont_commit=[]
for i in new_cont_commit:
    temp_list=[]
    for j in i:
        temp_j=j.replace(',','')
        new_j=float(temp_j)
        temp_list.append(new_j)
    real_cont_commit.append(temp_list)

# %%
commit_avg=[]
for i in real_cont_commit:
    if len(i)==5:
        commit_final=(i[0]+i[1]+i[2]+i[3]+i[4])/5
        commit_avg.append(commit_final)
    elif len(i)==4:
        commit_final2=(i[0]+i[1]+i[2]+i[3])/4
        commit_avg.append(commit_final2)
    elif len(i)==3:
        commit_final3=(i[0]+i[1]+i[2])/3
        commit_avg.append(commit_final3)
    elif len(i)==2:
        commit_final4=(i[0]+i[1])/2
        commit_avg.append(commit_final4)
    elif len(i)==1:
        commit_final5=i[0]
        commit_avg.append(commit_final5)
    else:
        commit_avg.append(0)

# %%
cont_add=[]
for i in repo_cont[2::4]:
    cont_add.append(i)

# %%
real_cont_add=[]
for i in cont_add:
    temp_list=[]
    for j in i:
        temp_j=j.replace(',','')
        new_j=float(temp_j)
        temp_list.append(new_j)
    real_cont_add.append(temp_list)

# %%
cont_add_avg=[]
for i in real_cont_add:
    if len(i)==5:
        cont_add_final=(i[0]+i[1]+i[2]+i[3]+i[4])/5
        cont_add_avg.append(cont_add_final)
    elif len(i)==4:
        cont_add_final2=(i[0]+i[1]+i[2]+i[3])/4
        cont_add_avg.append(cont_add_final2)
    elif len(i)==3:
        cont_add_final3=(i[0]+i[1]+i[2])/3
        cont_add_avg.append(cont_add_final3)
    elif len(i)==2:
        cont_add_final4=(i[0]+i[1])/2
        cont_add_avg.append(cont_add_final4)
    elif len(i)==1:
        cont_add_final5=i[0]
        cont_add_avg.append(cont_add_final5)
    else:
        cont_add_avg.append(0)

# %%
cont_del=[]
for i in repo_cont[3::4]:
    cont_del.append(i)

# %%
real_cont_del=[]
for i in cont_del:
    temp_list=[]
    for j in i:
        temp_j=j.replace(',','')
        new_j=float(temp_j)
        temp_list.append(new_j)
    real_cont_del.append(temp_list)

# %%
cont_del_avg=[]
for i in real_cont_del:
    if len(i)==5:
        cont_del_final=(i[0]+i[1]+i[2]+i[3]+i[4])/5
        cont_del_avg.append(cont_del_final)
    elif len(i)==4:
        cont_del_final2=(i[0]+i[1]+i[2]+i[3])/4
        cont_del_avg.append(cont_del_final2)
    elif len(i)==3:
        cont_del_final3=(i[0]+i[1]+i[2])/3
        cont_del_avg.append(cont_del_final3)
    elif len(i)==2:
        cont_del_final4=(i[0]+i[1])/2
        cont_del_avg.append(cont_del_final4)
    elif len(i)==1:
        cont_del_final5=i[0]
        cont_del_avg.append(cont_del_final5)
    else:
        cont_del_avg.append(0)

# %%
from pandas import Series
a=Series(data=cont_name)
b=Series(data=new_cont_commit)
c=Series(data=cont_add)
d=Series(data=cont_del)

# %%
cont_final=pd.concat([a,b,c,d],axis=1)
cont_final.columns=['name','commit','add','del']
cont_final
# Out:
#                                                    name  \
# 0     [SwordYork, futianfan, liber145, KevinLee1110,...
# 1     [mjanv, dikshantsagar, clouds56, Hrant-Khachat...
# 2                                       [priya-dwivedi]
# 3                                            [fchollet]
# 4       [MichalDanielDobrzanski, dgcampbe, hamolicious]
# ...                                                 ...
# 9983                                     [mallicksumit]
# 9984                                         [martahal]
# 9985                                                 []
# 9986                                          [deno750]
# 9987                                                 []
#
#                      commit                                add  \
# 0     [208, 164, 84, 37, 4]  [74,708, 9,976, 10,471, 5,090, 4]
# 1           [3, 3, 2, 2, 2]                 [145, 8, 17, 7, 6]
# 2                     [173]                        [2,402,497]
# ...

# %%
cont_name_count=[]
for i in cont_final['name']:
    cont_name_count.append(len(i))

# %%
repos_avg=[]
for i in tqdm(cont_name):
    if len(i)==5:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['repos'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['repos'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['repos'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['repos'].values[0]
        temp5=contributor_info.loc[contributor_info['name']==i[4]]
        r5=temp5['repos'].values[0]
        temp_final5=(r1+r2+r3+r4+r5)/5
        repos_avg.append(temp_final5)
    elif len(i)==4:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['repos'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['repos'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['repos'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['repos'].values[0]
        temp_final4=(r1+r2+r3+r4)/4
        repos_avg.append(temp_final4)
    elif len(i)==3:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['repos'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['repos'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['repos'].values[0]
        temp_final3=(r1+r2+r3)/3
        repos_avg.append(temp_final3)
    elif len(i)==2:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['repos'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['repos'].values[0]
        temp_final2=(r1+r2)/2
        repos_avg.append(temp_final2)
    elif len(i)==1:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['repos'].values[0]
        repos_avg.append(r1)
    else:
        repos_avg.append(0)

# %%
gists_avg=[]
for i in tqdm(cont_name):
    if len(i)==5:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['gists'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['gists'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['gists'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['gists'].values[0]
        temp5=contributor_info.loc[contributor_info['name']==i[4]]
        r5=temp5['gists'].values[0]
        temp_final5=(r1+r2+r3+r4+r5)/5
        gists_avg.append(temp_final5)
    elif len(i)==4:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['gists'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['gists'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['gists'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['gists'].values[0]
        temp_final4=(r1+r2+r3+r4)/4
        gists_avg.append(temp_final4)
    elif len(i)==3:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['gists'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['gists'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['gists'].values[0]
        temp_final3=(r1+r2+r3)/3
        gists_avg.append(temp_final3)
    elif len(i)==2:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['gists'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['gists'].values[0]
        temp_final2=(r1+r2)/2
        gists_avg.append(temp_final2)
    elif len(i)==1:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['gists'].values[0]
        gists_avg.append(r1)
    else:
        gists_avg.append(0)
# Out:
#   0%|          | 0/9988 [00:00<?, ?it/s]

# %%
followers_avg=[]
for i in tqdm(cont_name):
    if len(i)==5:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['followers'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['followers'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['followers'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['followers'].values[0]
        temp5=contributor_info.loc[contributor_info['name']==i[4]]
        r5=temp5['followers'].values[0]
        temp_final5=(r1+r2+r3+r4+r5)/5
        followers_avg.append(temp_final5)
    elif len(i)==4:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['followers'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['followers'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['followers'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['followers'].values[0]
        temp_final4=(r1+r2+r3+r4)/4
        followers_avg.append(temp_final4)
    elif len(i)==3:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['followers'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['followers'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['followers'].values[0]
        temp_final3=(r1+r2+r3)/3
        followers_avg.append(temp_final3)
    elif len(i)==2:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['followers'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['followers'].values[0]
        temp_final2=(r1+r2)/2
        followers_avg.append(temp_final2)
    elif len(i)==1:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['followers'].values[0]
        followers_avg.append(r1)
    else:
        followers_avg.append(0)
# Out:
#   0%|          | 0/9988 [00:00<?, ?it/s]

# %%
following_avg=[]
for i in tqdm(cont_name):
    if len(i)==5:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['following'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['following'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['following'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['following'].values[0]
        temp5=contributor_info.loc[contributor_info['name']==i[4]]
        r5=temp5['following'].values[0]
        temp_final5=(r1+r2+r3+r4+r5)/5
        following_avg.append(temp_final5)
    elif len(i)==4:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['following'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['following'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['following'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['following'].values[0]
        temp_final4=(r1+r2+r3+r4)/4
        following_avg.append(temp_final4)
    elif len(i)==3:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['following'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['following'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['following'].values[0]
        temp_final3=(r1+r2+r3)/3
        following_avg.append(temp_final3)
    elif len(i)==2:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['following'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['following'].values[0]
        temp_final2=(r1+r2)/2
        following_avg.append(temp_final2)
    elif len(i)==1:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['following'].values[0]
        following_avg.append(r1)
    else:
        following_avg.append(0)
# Out:
#   0%|          | 0/9988 [00:00<?, ?it/s]

# %%
gggggg=contributor_info['cont_star']

# %%
nnew_i=[]
for i in gggggg:
    if 'k' in str(i):
        temp_i=i.replace('k','')
        new_i=float(temp_i)
        new_i2=new_i*1000
        nnew_i.append(new_i2)
    else:
        new_i3=i=float(i)
        nnew_i.append(new_i3)

# %%
nnew_j=[]
for j in ffffff:
    if ',' in str(j):
        temp_j=j.replace(',','')
        new_j1=float(temp_j)
        nnew_j.append(new_j1)
    else:    
        new_j=float(j)
        nnew_j.append(new_j)

# %%
contributor_info['cont_star']=nnew_i

# %%
contributor_info['cont_commit']=nnew_j

# %%
cont_star_avg=[]
for i in tqdm(cont_name):
    if len(i)==5:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_star'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_star'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['cont_star'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['cont_star'].values[0]
        temp5=contributor_info.loc[contributor_info['name']==i[4]]
        r5=temp5['cont_star'].values[0]
        temp_final5=(r1+r2+r3+r4+r5)/5
        cont_star_avg.append(temp_final5)
    elif len(i)==4:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_star'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_star'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['cont_star'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['cont_star'].values[0]
        temp_final4=(r1+r2+r3+r4)/4
        cont_star_avg.append(temp_final4)
    elif len(i)==3:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_star'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_star'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['cont_star'].values[0]
        temp_final3=(r1+r2+r3)/3
        cont_star_avg.append(temp_final3)
    elif len(i)==2:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_star'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_star'].values[0]
        temp_final2=(r1+r2)/2
        cont_star_avg.append(temp_final2)
    elif len(i)==1:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_star'].values[0]
        cont_star_avg.append(r1)
    else:
        cont_star_avg.append(0)
# Out:
#   0%|          | 0/9988 [00:00<?, ?it/s]

# %%
cont_commit_avg=[]
for i in tqdm(cont_name):
    if len(i)==5:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_commit'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_commit'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['cont_commit'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['cont_commit'].values[0]
        temp5=contributor_info.loc[contributor_info['name']==i[4]]
        r5=temp5['cont_commit'].values[0]
        temp_final5=(r1+r2+r3+r4+r5)/5
        cont_commit_avg.append(temp_final5)
    elif len(i)==4:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_commit'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_commit'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['cont_commit'].values[0]
        temp4=contributor_info.loc[contributor_info['name']==i[3]]
        r4=temp4['cont_commit'].values[0]
        temp_final4=(r1+r2+r3+r4)/4
        cont_commit_avg.append(temp_final4)
    elif len(i)==3:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_commit'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_commit'].values[0]
        temp3=contributor_info.loc[contributor_info['name']==i[2]]
        r3=temp3['cont_commit'].values[0]
        temp_final3=(r1+r2+r3)/3
        cont_commit_avg.append(temp_final3)
    elif len(i)==2:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_commit'].values[0]
        temp2=contributor_info.loc[contributor_info['name']==i[1]]
        r2=temp2['cont_commit'].values[0]
        temp_final2=(r1+r2)/2
        cont_commit_avg.append(temp_final2)
    elif len(i)==1:
        temp1=contributor_info.loc[contributor_info['name']==i[0]]
        r1=temp1['cont_commit'].values[0]
        cont_commit_avg.append(r1)
    else:
        cont_commit_avg.append(0)
# Out:
#   0%|          | 0/9988 [00:00<?, ?it/s]

# %%
S_repo=Series(data=repos_avg)
S_gists=Series(data=gists_avg)
S_followers=Series(data=followers_avg)
S_following=Series(data=following_avg)
S_star=Series(data=cont_star_avg)
S_commit=Series(data=cont_commit_avg)

# %%
conts_avg=pd.concat([S_repo,S_gists,S_followers,S_following,S_star,S_commit],axis=1)
conts_avg.columns=['repo_avg','gists_avg','followers_avg','following_avg','star_avg','commit_avg']
conts_avg
# Out:
#       repo_avg  gists_avg  followers_avg  following_avg    star_avg  \
# 0         23.6        0.0          100.6           21.2  124.000000
# 1         39.6        2.8           58.0            7.0  113.000000
# 2         15.0       13.0         1955.0            0.0   13.000000
# 3         11.0       10.0        12727.0            0.0  120.000000
# 4         26.0        1.0           58.0           10.0  112.333333
# ...        ...        ...            ...            ...         ...
# 9983      14.0        0.0            0.0            0.0    0.000000
# 9984       8.0        0.0            0.0            0.0    0.000000
# 9985       0.0        0.0            0.0            0.0    0.000000
# 9986      29.0        0.0            6.0            1.0   94.000000
# 9987       0.0        0.0            0.0            0.0    0.000000
#
#       commit_avg
# 0     156.000000
# 1      49.800000
# 2     213.000000
# 3     980.000000
# 4      33.333333
# ...          ...
# 9983    7.000000
# ...

# %%
S_re_commit=Series(data=commit_avg)
S_add=Series(data=cont_add_avg)
S_del=Series(data=cont_del_avg)

# %%
conts2_avg=pd.concat([S_re_commit,S_add,S_del],axis=1)
conts2_avg.columns=['commits_repo_avg','add_avg','del_avg']
conts2_avg
# Out:
#       commits_repo_avg    add_avg  del_avg
# 0                 99.4    20049.8   6966.0
# 1                  2.4       36.6      9.2
# 2                173.0  2402497.0  35785.0
# 3                 11.0     2283.0    475.0
# 4                  4.0      456.0     31.0
# ...                ...        ...      ...
# 9983               6.0     2378.0    118.0
# 9984             146.0    17924.0  10980.0
# 9985               0.0        0.0      0.0
# 9986              15.0    24354.0   4856.0
# 9987               0.0        0.0      0.0
#
# [9988 rows x 3 columns]
